# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Reading the Files

# %%
X_order_report=pd.read_excel(r"C:\Users\Mohd Shadab\Downloads\Cointab Assignment\Company X - Order Report.xlsx")
X_order_report.sample(5)
# Out:
#      ExternOrderNo            SKU  Order Qty
# 155     2001809917  8904223819499        1.0
# 176     2001809794  8904223818454        1.0
# 166     2001809820  8904223818881        1.0
# 359     2001806533  8904223818706        1.0
# 167     2001809820  8904223818898        1.0

# %%
X_order_report.shape
# Out:
# (400, 3)

# %%
X_pincode=pd.read_excel(r"C:\Users\Mohd Shadab\Downloads\Cointab Assignment\Company X - Pincode Zones.xlsx")
X_pincode.sample(5)
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 17              121003            495671    d
# 98              121003            302019    b
# 13              121003            485001    d
# 80              121003            327025    b
# 101             121003            335001    b

# %%
X_pincode.shape
# Out:
# (124, 3)

# %%
X_SKU_master=pd.read_excel(r"C:\Users\Mohd Shadab\Downloads\Cointab Assignment\Company X - SKU Master.xlsx")
X_SKU_master.sample(5)
# Out:
#               SKU  Weight (g)
# 33  8904223819093         150
# 27  8904223818997         490
# 22  8904223818454         232
# 20  8904223818713         120
# 41  8904223819277         350

# %%
X_SKU_master.shape
# Out:
# (66, 2)

# %% [markdown]
# # EDA - Company X

# %% [markdown]
# # Merging company X data (X_order_report  +  X_SKU_master)

# %%
merged_data_X=X_order_report.merge(X_SKU_master,on='SKU',how='right')
merged_data_X.head()
# Out:
#    ExternOrderNo            SKU  Order Qty  Weight (g)
# 0     2001808801  8904223815682        1.0         210
# 1     2001820978  8904223815859        1.0         165
# 2     2001811363  8904223815859        1.0         165
# 3     2001811363  8904223815859        1.0         165
# 4     2001808801  8904223815859        1.0         165

# %%
merged_data_X.shape
# Out:
# (401, 4)

# %%
#check null
merged_data_X.isnull().sum()
# Out:
# ExternOrderNo    0
# SKU              0
# Order Qty        0
# Weight (g)       0
# dtype: int64

# %%
#check duplicates
merged_data_X.duplicated().sum()
# Out:
# 3

# %%
#drop duplicates
merged_data_X.drop_duplicates(inplace=True)

# %%
merged_data_X.duplicated().sum()
# Out:
# 0

# %%
# 0 hence duplicates have been treated

# %%
merged_data_X.describe()
# Out:
#        ExternOrderNo   Order Qty  Weight (g)
# count   3.980000e+02  398.000000  398.000000
# mean    2.001811e+09    1.296482  180.736181
# std     5.196911e+03    0.921360   91.529287
# min     2.001806e+09    1.000000   10.000000
# 25%     2.001807e+09    1.000000  120.250000
# 50%     2.001809e+09    1.000000  133.000000
# 75%     2.001812e+09    1.000000  240.000000
# max     2.001827e+09    8.000000  600.000000

# %%
# Max orders - 8
# Max Weight - 600 g

# %%
merged_data_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 400
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  398 non-null    int64
#  1   SKU            398 non-null    object
#  2   Order Qty      398 non-null    float64
#  3   Weight (g)     398 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.5+ KB

# %% [markdown]
# # Pincode data of company X (not in merged data)

# %%
X_pincode.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d
# 3             121003            143001    b
# 4             121003            515591    d

# %%
X_pincode.isnull().sum()
# Out:
# Warehouse Pincode    0
# Customer Pincode     0
# Zone                 0
# dtype: int64

# %%
#check duplicates
X_pincode.duplicated().sum()
# Out:
# 16

# %%
#drop duplicates
X_pincode.drop_duplicates(inplace=True)

# %%
#check duplicates
X_pincode.duplicated().sum()
# Out:
# 0

# %%
# 0 hence duplicates have been treated

# %%
# To make the statistical analysis of pincodes to make sense converting them to category type datatypes
X_pin_cat=X_pincode.select_dtypes(include=['int64']).astype('category')

# %%
X_pincode.drop(['Warehouse Pincode','Customer Pincode'],axis=1,inplace=True)

# %%
X_pincode
# Out:
#     Zone
# 0      d
# 1      d
# 2      d
# 3      b
# 4      d
# ..   ...
# 114    b
# 115    b
# 119    b
# 120    b
# 121    b
#
# [108 rows x 1 columns]

# %%
X_pincode=pd.concat([X_pincode,X_pin_cat],axis=1)
X_pincode
# Out:
#     Zone Warehouse Pincode Customer Pincode
# 0      d            121003           507101
# 1      d            121003           486886
# 2      d            121003           532484
# 3      b            121003           143001
# 4      d            121003           515591
# ..   ...               ...              ...
# 114    b            121003           324008
# 115    b            121003           302020
# 119    b            121003           325207
# 120    b            121003           303702
# 121    b            121003           313301
#
# [108 rows x 3 columns]

# %%
X_pincode.describe()
# Out:
#        Zone  Warehouse Pincode  Customer Pincode
# count   108                108               108
# unique    3                  1               108
# top       b             121003            140301
# freq     64                108                 1

# %%
# Most orders belong to zone b i.e., 64
# Most orders are shipped from '121003' Pincode i.e., 108

# %%
X_pincode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 0 to 121
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Zone               108 non-null    object
#  1   Warehouse Pincode  108 non-null    category
#  2   Customer Pincode   108 non-null    category
# dtypes: category(2), object(1)
# memory usage: 6.9+ KB

# %%
#Total pincodes beonging to zones

# %%
X_pincode['Zone'].value_counts().plot.bar();

# %%
# most pincodes belong to zone b

# %% [markdown]
# # Courier company's data.

# %%
courier_invoice=pd.read_excel(r"C:\Users\Mohd Shadab\Downloads\Cointab Assignment\Courier Company - Invoice.xlsx")
courier_invoice.sample(5)
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 51   1091117229290  2001807004            0.68             121003
# 122  1091121844806  2001811475            0.50             121003
# 84   1091121185863  2001821502            0.60             121003
# 88   1091120352712  2001819252            0.30             121003
# 90   1091117222360  2001806304            0.71             121003
#
#      Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 51             410206    d  Forward charges                  90.2
# 122            173212    b  Forward charges                  33.0
# 84             314401    d  Forward charges                  90.2
# 88             174101    b  Forward charges                  33.0
# 90             302017    d  Forward charges                  90.2

# %% [markdown]
# # EDA - Courier company

# %%
courier_invoice.shape
# Out:
# (124, 8)

# %%
courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %%
courier_invoice['Customer Pincode']=courier_invoice['Customer Pincode'].astype('category')
courier_invoice['Warehouse Pincode']=courier_invoice['Warehouse Pincode'].astype('category')

# %%
courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    category
#  4   Customer Pincode      124 non-null    category
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: category(2), float64(2), int64(2), object(2)
# memory usage: 11.2+ KB

# %%
courier_invoice.describe()
# Out:
#            AWB Code      Order ID  Charged Weight  Billing Amount (Rs.)
# count  1.240000e+02  1.240000e+02      124.000000            124.000000
# mean   1.091118e+12  2.001811e+09        0.956048            110.066129
# std    1.473661e+06  5.167329e+03        0.662815             64.060832
# min    1.091117e+12  2.001806e+09        0.150000             33.000000
# 25%    1.091117e+12  2.001807e+09        0.667500             86.700000
# 50%    1.091117e+12  2.001809e+09        0.725000             90.200000
# 75%    1.091119e+12  2.001812e+09        1.100000            135.000000
# max    1.091122e+12  2.001827e+09        4.130000            403.800000

# %%
# Most Charged weight is 4.13
# Highest billing amount is found to be 403.8 Rs.

# %%
courier_invoice[['Warehouse Pincode','Customer Pincode']].describe()
# Out:
#         Warehouse Pincode  Customer Pincode
# count                 124               124
# unique                  1               108
# top                121003            302017
# freq                  124                 5

# %%
courier_company_rates=pd.read_excel(r"C:\Users\Mohd Shadab\Downloads\Cointab Assignment\Courier Company - Rates.xlsx")
courier_company_rates
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
courier_company_rates.shape
# Out:
# (1, 20)

# %%
courier_company_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fwd_a_fixed       1 non-null      float64
#  1   fwd_a_additional  1 non-null      float64
#  2   fwd_b_fixed       1 non-null      int64
#  3   fwd_b_additional  1 non-null      float64
#  4   fwd_c_fixed       1 non-null      float64
#  5   fwd_c_additional  1 non-null      float64
#  6   fwd_d_fixed       1 non-null      float64
#  7   fwd_d_additional  1 non-null      float64
#  8   fwd_e_fixed       1 non-null      float64
#  9   fwd_e_additional  1 non-null      float64
#  10  rto_a_fixed       1 non-null      float64
#  11  rto_a_additional  1 non-null      float64
#  12  rto_b_fixed       1 non-null      float64
#  13  rto_b_additional  1 non-null      float64
#  14  rto_c_fixed       1 non-null      float64
#  15  rto_c_additional  1 non-null      float64
# ...

# %% [markdown]
# # Assigning Weight slabs

# %% [markdown]
# # Company X

# %%
merged_data_X.head()
# Out:
#    ExternOrderNo            SKU  Order Qty  Weight (g)
# 0     2001808801  8904223815682        1.0         210
# 1     2001820978  8904223815859        1.0         165
# 2     2001811363  8904223815859        1.0         165
# 4     2001808801  8904223815859        1.0         165
# 5     2001808675  8904223815859        1.0         165

# %%
merged_data_X['Total Weight (kg)']=(merged_data_X['Weight (g)']*merged_data_X['Order Qty'])/1000

# %%
merged_data_X.sample(5)
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight (kg)
# 83      2001810697  8904223818706        1.0         127              0.127
# 309     2001811192  8904223818881        1.0         140              0.140
# 347     2001808675  8904223819369        1.0         170              0.170
# 315     2001809820  8904223819277        1.0         350              0.350
# 203     2001817093  8904223818874        1.0         100              0.100

# %%
plt.figure(figsize=(10,10))
merged_data_X['Total Weight (kg)'].value_counts().sort_values(ascending=False).head(10).plot.pie(autopct='%.2f');

# %%
# Most number of orders total weight is around 240 gm (31.63% of total orders) followed by 127 (19.39% of total order)

# %%
def weight_slab(wt):
    if wt<=0.5:
        return 0.5
    elif wt>0.5 and wt<=1:
        return 1
    elif wt>1 and wt<=1.5:
        return 1.5
    elif wt>1.5 and wt<=2:
        return 2
    else:
        return int(wt)+0.5

# %%
merged_data_X['Weight Slab company X']=merged_data_X['Total Weight (kg)'].apply(weight_slab)

# %%
merged_data_X
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight (kg)  \
# 0       2001808801  8904223815682        1.0         210              0.210
# 1       2001820978  8904223815859        1.0         165              0.165
# 2       2001811363  8904223815859        1.0         165              0.165
# 4       2001808801  8904223815859        1.0         165              0.165
# 5       2001808675  8904223815859        1.0         165              0.165
# ..             ...            ...        ...         ...                ...
# 396     2001806733  8904223819512        1.0         210              0.210
# 397     2001811306  8904223819543        1.0         300              0.300
# 398     2001827036     SACHETS001        1.0          10              0.010
# 399     2001825261     SACHETS001        1.0          10              0.010
# 400     2001819252     SACHETS001        1.0          10              0.010
#
#      Weight Slab company X
# 0                      0.5
# ...

# %%
merged_data_X['Weight Slab company X'].value_counts().plot.bar();

# %%
merged_data_X=merged_data_X.rename(columns={'ExternOrderNo':'Order ID'})
merged_data_X.head()
# Out:
#      Order ID            SKU  Order Qty  Weight (g)  Total Weight (kg)  \
# 0  2001808801  8904223815682        1.0         210              0.210
# 1  2001820978  8904223815859        1.0         165              0.165
# 2  2001811363  8904223815859        1.0         165              0.165
# 4  2001808801  8904223815859        1.0         165              0.165
# 5  2001808675  8904223815859        1.0         165              0.165
#
#    Weight Slab company X
# 0                    0.5
# 1                    0.5
# 2                    0.5
# 4                    0.5
# 5                    0.5

# %%
courier_invoice_X = X_pincode.drop_duplicates(subset=['Customer Pincode'])
courier_X=courier_invoice[['Order ID','AWB Code','Customer Pincode','Type of Shipment']]
pincode_merged_courier=courier_X.merge(courier_invoice_X,on='Customer Pincode')
pincode_merged_courier.sample()
pincode_merged_courier=pincode_merged_courier.rename(columns={'Zone':'Zone as per X'})
pincode_merged_courier
# Out:
#        Order ID       AWB Code Customer Pincode         Type of Shipment  \
# 0    2001806232  1091117222124           507101          Forward charges
# 1    2001806273  1091117222194           486886          Forward charges
# 2    2001806408  1091117222931           532484          Forward charges
# 3    2001806458  1091117223244           143001          Forward charges
# 4    2001807012  1091117229345           515591          Forward charges
# ..          ...            ...              ...                      ...
# 119  2001811039  1091117904860           302020          Forward charges
# 120  2001811305  1091121846136           302020          Forward charges
# 121  2001812941  1091118551656           325207          Forward charges
# 122  2001809383  1091117614452           303702  Forward and RTO charges
# 123  2001820978  1091120922803           313301          Forward charges
#
#     Zone as per X Warehouse Pincode
# 0               d            121003
# ...

# %%
merged_data_X_pincode_courier=merged_data_X.merge(pincode_merged_courier,on='Order ID')
merged_data_X_pincode_courier.sample(5)
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Total Weight (kg)  \
# 23   2001817093  8904223818881        1.0         140              0.140
# 289  2001807084  8904223818706        1.0         127              0.127
# 320  2001806446  8904223818942        1.0         133              0.133
# 366  2001807036  8904223819291        4.0         112              0.448
# 1    2001808801  8904223815859        1.0         165              0.165
#
#      Weight Slab company X       AWB Code Customer Pincode  \
# 23                     0.5  1091121485824           244001
# 289                    0.5  1091117323215           742103
# 320                    0.5  1091117223211           382830
# 366                    0.5  1091117323005           516503
# 1                      0.5  1091117437680           335001
#
#             Type of Shipment Zone as per X Warehouse Pincode
# 23   Forward and RTO charges             b            121003
# ...

# %%
merged_data_X_pincode_courier.rename(columns={})
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Total Weight (kg)  \
# 0    2001808801  8904223815682        1.0         210              0.210
# 1    2001808801  8904223815859        1.0         165              0.165
# 2    2001808801  8904223815866        2.0         113              0.226
# 3    2001808801  8904223817273        2.0          65              0.130
# 4    2001820978  8904223815859        1.0         165              0.165
# ..          ...            ...        ...         ...                ...
# 393  2001809917  8904223819505        1.0         210              0.210
# 394  2001809917  8904223819499        1.0         210              0.210
# 395  2001809917  8904223819512        1.0         210              0.210
# 396  2001806885  8904223819499        2.0         210              0.420
# 397  2001806768  8904223819512        4.0         210              0.840
#
#      Weight Slab company X       AWB Code Customer Pincode  \
# ...

# %% [markdown]
# # Courier company

# %%
courier_invoice.sample(5)
# Out:
#           AWB Code    Order ID  Charged Weight Warehouse Pincode  \
# 56   1091117616121  2001809592            1.50            121003
# 5    1091117229555  2001806686            0.15            121003
# 75   1091119367193  2001816131            0.70            121003
# 119  1091118551656  2001812941            0.73            121003
# 45   1091117226221  2001806652            0.69            121003
#
#     Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 56            244713    b  Forward charges                  89.6
# 5             326502    d  Forward charges                  45.4
# 75            302017    d  Forward charges                  90.2
# 119           325207    d  Forward charges                  90.2
# 45            403401    d  Forward charges                  90.2

# %%
plt.figure(figsize=(10,10))
courier_invoice['Charged Weight'].value_counts().sort_values(ascending=False).head(10).plot.pie(autopct='%.2f ');

# %%
courier_invoice['Weight Slab company courier']=courier_invoice['Charged Weight'].apply(weight_slab)

# %%
courier_invoice['Weight Slab company courier'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
courier_invoice.head()
# Out:
#         AWB Code    Order ID  Charged Weight Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30            121003
# 1  1091117222194  2001806273            1.00            121003
# 2  1091117222931  2001806408            2.50            121003
# 3  1091117223244  2001806458            1.00            121003
# 4  1091117229345  2001807012            0.15            121003
#
#   Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)  \
# 0           507101    d  Forward charges                 135.0
# 1           486886    d  Forward charges                  90.2
# 2           532484    d  Forward charges                 224.6
# 3           143001    b  Forward charges                  61.3
# 4           515591    d  Forward charges                  45.4
#
#    Weight Slab company courier
# 0                          1.5
# 1                          1.0
# 2                          2.5
# 3                          1.0
# 4                          0.5

# %% [markdown]
# # Expected Charges

# %%
total_Expected_charge=[]
for i in range(len(merged_data_X_pincode_courier)):
    fwd_category='fwd_'+merged_data_X_pincode_courier['Zone as per X'][i]
    fwd_fixed=courier_company_rates[fwd_category+'_fixed'][0]
    fwd_additional=courier_company_rates[fwd_category+'_additional'][0]
    rto_category='rto_'+merged_data_X_pincode_courier['Zone as per X'][i]
    rto_fixed=courier_company_rates[rto_category+'_fixed'][0]
    rto_additional=courier_company_rates[rto_category+'_additional'][0]
    if merged_data_X_pincode_courier['Type of Shipment'][i]=='Forward charges':
        if merged_data_X_pincode_courier['Weight Slab company X'][i]<=0.5:
            total_Expected_charge.append(fwd_fixed)
        else:
            additional_weight=(merged_data_X_pincode_courier['Weight Slab company X'][i]-0.5)/0.5
            total_Expected_charge.append(fwd_fixed+additional_weight*fwd_additional)
    if merged_data_X_pincode_courier['Type of Shipment'][i]=='Forward and RTO charges':
        if merged_data_X_pincode_courier['Weight Slab company X'][i]<=0.5:
            total_Expected_charge.append(fwd_fixed+rto_fixed)
        else:
            additional_weight=(merged_data_X_pincode_courier['Weight Slab company X'][i]-0.5)/0.5
            total_Expected_charge.append(fwd_fixed+additional_weight*(fwd_additional+rto_additional))

merged_data_X_pincode_courier['Expected Charge As Per X (Rs.)']=total_Expected_charge

# %%
merged_data_X_pincode_courier
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Total Weight (kg)  \
# 0    2001808801  8904223815682        1.0         210              0.210
# 1    2001808801  8904223815859        1.0         165              0.165
# 2    2001808801  8904223815866        2.0         113              0.226
# 3    2001808801  8904223817273        2.0          65              0.130
# 4    2001820978  8904223815859        1.0         165              0.165
# ..          ...            ...        ...         ...                ...
# 393  2001809917  8904223819505        1.0         210              0.210
# 394  2001809917  8904223819499        1.0         210              0.210
# 395  2001809917  8904223819512        1.0         210              0.210
# 396  2001806885  8904223819499        2.0         210              0.420
# 397  2001806768  8904223819512        4.0         210              0.840
#
#      Weight Slab company X       AWB Code Customer Pincode  \
# ...

# %%
merged_data_X_pincode_courier=merged_data_X_pincode_courier.rename(columns={'AWB Code':'AWB Number','Total Weight (kg)':'Total weight as per X (KG)','Weight Slab company X':'Weight slab as per X (KG)','Zone as per X':'Delivery Zone as per X'})

# %%
merged_data_X_pincode_courier.head()
# Out:
#      Order ID            SKU  Order Qty  Weight (g)  \
# 0  2001808801  8904223815682        1.0         210
# 1  2001808801  8904223815859        1.0         165
# 2  2001808801  8904223815866        2.0         113
# 3  2001808801  8904223817273        2.0          65
# 4  2001820978  8904223815859        1.0         165
#
#    Total weight as per X (KG)  Weight slab as per X (KG)     AWB Number  \
# 0                       0.210                        0.5  1091117437680
# 1                       0.165                        0.5  1091117437680
# 2                       0.226                        0.5  1091117437680
# 3                       0.130                        0.5  1091117437680
# 4                       0.165                        0.5  1091120922803
#
#   Customer Pincode Type of Shipment Delivery Zone as per X Warehouse Pincode  \
# 0           335001  Forward charges                      b            121003
# ...

# %%
merged_data_X_pincode_courier.columns
# Out:
# Index(['Order ID', 'SKU', 'Order Qty', 'Weight (g)',
#        'Total weight as per X (KG)', 'Weight slab as per X (KG)', 'AWB Number',
#        'Customer Pincode', 'Type of Shipment', 'Delivery Zone as per X',
#        'Warehouse Pincode', 'Expected Charge As Per X (Rs.)'],
#       dtype='object')

# %%
X_company_final=merged_data_X_pincode_courier[['Order ID','AWB Number', 'Total weight as per X (KG)',
                                               'Weight slab as per X (KG)','Delivery Zone as per X',
                                               'Expected Charge As Per X (Rs.)']]

# %%
X_company_final.sample()
# Out:
#       Order ID     AWB Number  Total weight as per X (KG)  \
# 20  2001817093  1091121485824                         0.1
#
#     Weight slab as per X (KG) Delivery Zone as per X  \
# 20                        0.5                      b
#
#     Expected Charge As Per X (Rs.)
# 20                            53.5

# %%
courier_invoice=courier_invoice.rename(columns={'Charged Weight':'Total weight as per Courier Company (KG)','Weight Slab company courier':'Weight slab charged by Courier Company (KG)','Zone':'Delivery Zone charged by Courier Company','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)'})

# %%
courier_invoice.sample(5)
# Out:
#           AWB Code    Order ID  Total weight as per Courier Company (KG)  \
# 5    1091117229555  2001806686                                      0.15
# 73   1091118925110  2001814580                                      0.15
# 102  1091117436652  2001808585                                      0.72
# 60   1091117324011  2001807241                                      0.79
# 35   1091117222080  2001806229                                      0.71
#
#     Warehouse Pincode Customer Pincode  \
# 5              121003           326502
# 73             121003           322255
# 102            121003           175101
# 60             121003           341001
# 35             121003           421204
#
#     Delivery Zone charged by Courier Company         Type of Shipment  \
# 5                                          d          Forward charges
# 73                                         d  Forward and RTO charges
# 102                                        b          Forward charges
# ...

# %%
courier_invoice.columns
# Out:
# Index(['AWB Code', 'Order ID', 'Total weight as per Courier Company (KG)',
#        'Warehouse Pincode', 'Customer Pincode',
#        'Delivery Zone charged by Courier Company', 'Type of Shipment',
#        'Charges Billed by Courier Company (Rs.)',
#        'Weight slab charged by Courier Company (KG)'],
#       dtype='object')

# %%
Courier_company_final=courier_invoice[['Order ID','Total weight as per Courier Company (KG)','Delivery Zone charged by Courier Company','Charges Billed by Courier Company (Rs.)','Weight slab charged by Courier Company (KG)']]

# %%
Courier_company_final.head()
# Out:
#      Order ID  Total weight as per Courier Company (KG)  \
# 0  2001806232                                      1.30
# 1  2001806273                                      1.00
# 2  2001806408                                      2.50
# 3  2001806458                                      1.00
# 4  2001807012                                      0.15
#
#   Delivery Zone charged by Courier Company  \
# 0                                        d
# 1                                        d
# 2                                        d
# 3                                        b
# 4                                        d
#
#    Charges Billed by Courier Company (Rs.)  \
# 0                                    135.0
# 1                                     90.2
# 2                                    224.6
# 3                                     61.3
# 4                                     45.4
#
#    Weight slab charged by Courier Company (KG)
# ...

# %%
output_merged=X_company_final.merge(Courier_company_final,on='Order ID')

# %%
output_merged.sample(5)
# Out:
#        Order ID     AWB Number  Total weight as per X (KG)  \
# 359  2001807362  1091117324394                       0.224
# 87   2001807058  1091117323112                       0.290
# 347  2001823564  1091121666133                       0.224
# 263  2001807956  1091117327275                       0.133
# 40   2001811305  1091121846136                       0.210
#
#      Weight slab as per X (KG) Delivery Zone as per X  \
# 359                        0.5                      d
# 87                         0.5                      b
# 347                        0.5                      d
# 263                        0.5                      b
# 40                         0.5                      b
#
#      Expected Charge As Per X (Rs.)  Total weight as per Courier Company (KG)  \
# 359                            45.4                                      2.00
# 87                             33.0                                      1.15
# ...

# %% [markdown]
# # Difference between expected and Billed charges

# %%
output_merged['Difference Between Expected Charges and Billed Charges (Rs.)']=output_merged['Expected Charge As Per X (Rs.)']-output_merged['Charges Billed by Courier Company (Rs.)']

# %%
output_data_1=output_merged

# %%
output_data_1.head()
# Out:
#      Order ID     AWB Number  Total weight as per X (KG)  \
# 0  2001808801  1091117437680                       0.210
# 1  2001808801  1091117437680                       0.165
# 2  2001808801  1091117437680                       0.226
# 3  2001808801  1091117437680                       0.130
# 4  2001820978  1091120922803                       0.165
#
#    Weight slab as per X (KG) Delivery Zone as per X  \
# 0                        0.5                      b
# 1                        0.5                      b
# 2                        0.5                      b
# 3                        0.5                      b
# 4                        0.5                      b
#
#    Expected Charge As Per X (Rs.)  Total weight as per Courier Company (KG)  \
# 0                            33.0                                       0.8
# 1                            33.0                                       0.8
# ...

# %%
count1=output_merged[output_merged['Difference Between Expected Charges and Billed Charges (Rs.)']==0]['Difference Between Expected Charges and Billed Charges (Rs.)']
total_count1=len(count1)
amount1=count1.sum()
count2=output_merged[output_merged['Difference Between Expected Charges and Billed Charges (Rs.)']<0]['Difference Between Expected Charges and Billed Charges (Rs.)']
total_count2=len(count2)
amount2=abs(output_merged['Difference Between Expected Charges and Billed Charges (Rs.)'].sum())
count3=output_merged[output_merged['Difference Between Expected Charges and Billed Charges (Rs.)']>0]['Difference Between Expected Charges and Billed Charges (Rs.)']
total_count3=len(count3)
amount3=count3.sum()

dict2={'':['Total orders where X has been correctly charged','Total orders where X has been overcharged','Total orders where X has been undercharged'],
        'Count':[total_count1,total_count2,total_count3],
        'Amount(Rs.)':[amount1,amount2,amount3]}

# %%
output_data_2=pd.DataFrame(dict2,index=[0,1,2])
output_data_2
# Out:
#                                                     Count  Amount(Rs.)
# 0  Total orders where X has been correctly charged     12          0.0
# 1        Total orders where X has been overcharged    377      31425.5
# 2       Total orders where X has been undercharged      9        165.2

# %% [markdown]
# # Output to Excel

# %%
output_data_1.to_excel('Resultant Output.xlsx',index=False)

print('File saved')
# Out:
# File saved

# %%
output_data_2.to_excel('Summary.xlsx',index=False)

print('File saved')
# Out:
# File saved
